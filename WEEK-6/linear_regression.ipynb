# %% [markdown]
# <a href="https://colab.research.google.com/github/vigneshgoud4099/2025_2026-4099-vignesh-ai-b-ds/blob/main/WEEK-6/linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
X=np.array([1,2,3,4,5]).reshape(-1,1)
Y=np.array([30,35,50,55,65])
model=LinearRegression()
model.fit(X,Y)
prtediction=model.predict(X)
print("slop:",model.coef_)
print("intercept:",model.intercept_)
plt.scatter(X,Y)
plt.xlabel("Experience")
plt.ylabel("Salary")
plt.title("Linear Regression")
plt.show()
# Out:
# slop: [9.]
# intercept: 19.999999999999993
