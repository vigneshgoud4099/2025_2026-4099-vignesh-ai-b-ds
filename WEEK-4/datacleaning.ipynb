# %% [markdown]
# <a href="https://colab.research.google.com/github/vigneshgoud4099/2025_2026-4099-vignesh-ai-b-ds/blob/main/WEEK-4/datacleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import Library
import pandas as pd

# Load Dataset from URL
url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(url)


# Original Dataset Info

print("=== Original Dataset Info ===")
print(df.info())
print("\nMissing Values Before Cleaning:")
print(df.isnull().sum())
print("\nFirst 5 rows:\n", df.head())


# DATA CLEANING OPERATIONS

# 1. Handle Missing Values
df['Age'] = df['Age'].fillna(df['Age'].median())
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])

print("\n=== Missing Values After Filling ===")
print(df.isnull().sum())

# 2. Drop Cabin column (too many missing values)
df = df.drop(columns=['Cabin'])
print("\n=== Columns After Dropping 'Cabin' ===")
print(df.columns)
# 3. Remove Duplicate Rows
before_duplicates = df.shape[0]
df = df.drop_duplicates()
after_duplicates = df.shape[0]
print(f"\nRemoved {before_duplicates - after_duplicates} duplicate rows")
# 4. Convert Data Types
df['Survived'] = df['Survived'].astype('category')
df['Pclass'] = df['Pclass'].astype('category')
print("\n=== Data Types After Conversion ===")
print(df.dtypes)

# 5. Rename Columns to lowercase
df.columns = df.columns.str.lower()
print("\n=== Columns After Renaming ===")
print(df.columns)

# Remove Outliers (Age using IQR method)
Q1 = df['age'].quantile(0.25)
Q3 = df['age'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

before_outliers = df.shape[0]
df = df[(df['age'] >= lower_bound) & (df['age'] <= upper_bound)]
after_outliers = df.shape[0]
print(f"\nRemoved {before_outliers - after_outliers} outlier rows based on Age")

# Save Cleaned Dataset
df.to_csv("cleaned_titanic.csv", index=False)
print("\nData Cleaning Completed Successfully!")
print("Cleaned file saved as: cleaned_titanic.csv")
# View first 5 cleaned rows
print("\n=== First 5 rows of Cleaned Dataset ===")
print(df.head())
# Out:
# === Original Dataset Info ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# None
#
# Missing Values Before Cleaning:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# ...
